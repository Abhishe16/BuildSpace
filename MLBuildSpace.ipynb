# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Admin\Downloads\MLBuildSpace.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/MLBuildSpace.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/data.csv")
df1 = df
df1.head(10)
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0       0.01020         0.833       204600   0.434
# 1           1       0.19900         0.743       326933   0.359
# 2           2       0.03440         0.838       185707   0.412
# 3           3       0.60400         0.494       199413   0.338
# 4           4       0.18000         0.678       392893   0.561
# 5           5       0.00479         0.804       251333   0.560
# 6           6       0.01450         0.739       241400   0.472
# 7           7       0.02020         0.266       349667   0.348
# 8           8       0.04810         0.603       202853   0.944
# 9           9       0.00208         0.836       226840   0.603
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# ...

# %% [markdown]
# # TASK 1_1

# %%
task1_1_1_1= df[df['energy']>0.4]
task1_1_1=task1_1_1_1[['song_title']]
task1_1_1.head()
# Out:
#        song_title
# 0        Mask Off
# 2    Xanny Family
# 4  Parallel Lines
# 5        Sneakin’
# 6     Childs Play

# %% [markdown]
# # TASK 1_2

# %%
task1_1_2_1 = df[df['duration_ms']>300000]
task1_1_2_2 = task1_1_2_1.sort_values('tempo',ascending=False)[['song_title','artist']]
task1_1_2_2
# Out:
#                                              song_title            artist
# 412                                              Lazuli       Beach House
# 942                                            Remember       Gino Soccio
# 729                                          Bumpy Road  Destruction Unit
# 1560                       Emperor Jones - Instrumental        Joe Lovano
# 992   Swerve... the reeping of all that is worthwhil...   Shabazz Palaces
# ...                                                 ...               ...
# 1876           Nocturne No.1 In B Flat Minor, Op.9 No.1   Frédéric Chopin
# 1561                                            Isadora   Christian Scott
# 1512                                  I'll Let You Know   David Hazeltine
# 1576                               My Little Brown Book    Duke Ellington
# 1562                                I Remember Clifford        Lee Morgan
#
# [321 rows x 2 columns]

# %% [markdown]
# # TASK 1_3

# %%
task1_1_3_1 = df[df['artist']=='Drake'][df['energy']>0.5]
task1_1_3_2 = task1_1_3_1[['song_title']]
task1_1_3_2
# Out:
# <ipython-input-6-826c4d344485>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   task1_1_3_1 = df[df['artist']=='Drake'][df['energy']>0.5]
#                    song_title
# 5                    Sneakin’
# 37                    Jumpman
# 117             Hotline Bling
# 154                 Big Rings
# 440                 Headlines
# 589   Started From the Bottom
# 779   0 To 100 / The Catch Up
# 1016         Skepta Interlude
# 1218          Best I Ever Had
# 1223                Take Care

# %% [markdown]
# # TASK 2_1

# %%
task1_2_1 = df.sort_values('instrumentalness',ascending=False)[['instrumentalness','song_title','artist']].head(10)
task1_2_1
# Out:
#       instrumentalness                            song_title  \
# 1313             0.976                       Senseless Order
# 271              0.968  So Destroyed (channeling Rage Peace)
# 1575             0.964             A Hundred Dreams from Now
# 1619             0.958                                 Raven
# 725              0.957                     Strandbar (disko)
# 1546             0.956                        Almas vaggvisa
# 1322             0.955                            Pitchblack
# 1349             0.954                       Prismatic Abyss
# 1661             0.954                               Yebisah
# 121              0.952                        Chasing Heaven
#
#                         artist
# 1313        Signs of the Swarm
# 271                Prince Rama
# 1575                Ray Bryant
# 1619             John Dahlbäck
# 725                 Todd Terje
# 1546         Jan Lundgren Trio
# 1322  Walking Dead On Broadway
# 1349           Aversions Crown
# ...

# %%
dataf1 = df['artist'].value_counts().head(10).reset_index().drop(columns=['artist'])
dataf1.columns = [['artist']]
dataf2=df.groupby(by = 'artist')[['artist','tempo']]
dataf2r
#dataf2 = dataf2.set_index(['artist'])

# %% [markdown]
# # TASK 2_2

# %%
task1_2_2 = df.groupby(by = 'artist')[['tempo']].mean()
task1_2_2.head(10)
# Out:
#                               tempo
# artist
# !!!                      120.004000
# *NSYNC                   140.488375
# 10cm                     116.955500
# 2 Chainz                 111.187333
# 2 LIVE CREW              131.644000
# 20th Century Steel Band  107.363000
# 21 Savage                140.063000
# 2milly                   135.450000
# 3LW                       88.933000
# 4 Non Blondes            134.369000
